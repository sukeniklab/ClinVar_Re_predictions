# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('../data/allClinvarMissense.csv',header=0,index_col=0)

# %%
data.columns
# Out:
# Index(['upID', 'geneID', 'N_res', 'N_disordered', 'N_ordered', 'varID',
#        'change', 'orig', 'pos', 'mut', 'wtRe', 'mutRe', 'wtRe_local',
#        'mutRe_local', 'changeType', 'res_disorder', 'disease', 'signi'],
#       dtype='object')

# %%
fig,ax=plt.subplots(figsize=[7,3])
bins=np.linspace(0,1,50)
ax.hist(data['res_disorder'],bins=bins)
# Out:
# (array([208014., 111765.,  83502.,  64233.,  50261.,  40011.,  32258.,
#          27306.,  22704.,  19416.,  16878.,  14573.,  13178.,  11571.,
#          10777.,   9827.,   9202.,   8490.,   7801.,   7294.,   7000.,
#           6852.,   6446.,   6137.,   6009.,   5795.,   5777.,   5808.,
#           5848.,   5721.,   5799.,   5777.,   5898.,   6174.,   6248.,
#           6395.,   6541.,   7078.,   7806.,   8574.,   9589.,  11165.,
#          14084.,  17783.,  23706.,  31437.,  41773.,  51337.,  97951.]),
#  array([0.        , 0.02040816, 0.04081633, 0.06122449, 0.08163265,
#         0.10204082, 0.12244898, 0.14285714, 0.16326531, 0.18367347,
#         0.20408163, 0.2244898 , 0.24489796, 0.26530612, 0.28571429,
#         0.30612245, 0.32653061, 0.34693878, 0.36734694, 0.3877551 ,
#         0.40816327, 0.42857143, 0.44897959, 0.46938776, 0.48979592,
#         0.51020408, 0.53061224, 0.55102041, 0.57142857, 0.59183673,
#         0.6122449 , 0.63265306, 0.65306122, 0.67346939, 0.69387755,
#         0.71428571, 0.73469388, 0.75510204, 0.7755102 , 0.79591837,
#         0.81632653, 0.83673469, 0.85714286, 0.87755102, 0.89795918,
#         0.91836735, 0.93877551, 0.95918367, 0.97959184, 1.        ]),
#  <BarContainer object of 49 artists>)

# %%
sl_folded = data[data['res_disorder']<0.5]
sl_idr = data[data['res_disorder']>0.5]
sl_idr.groupby('signi').count()
# Out:
#                                                       upID  geneID   N_res  \
# signi
# Affects                                                  7       7       7
# Benign                                               10494   10494   10494
# Benign/Likely_benign                                  3919    3919    3919
# Benign/Likely_benign|association                         1       1       1
# Benign/Likely_benign|other|risk_factor                   1       1       1
# Benign|association                                       1       1       1
# Conflicting_classifications_of_pathogenicity         17464   17464   17464
# Conflicting_classifications_of_pathogenicity|as...       1       1       1
# Conflicting_classifications_of_pathogenicity|ri...       2       2       2
# Likely_benign                                        24292   24292   24292
# Likely_pathogenic                                     3243    3243    3243
# Likely_pathogenic/Likely_risk_allele                     1       1       1
# Likely_pathogenic;_low_penetrance                        1       1       1
# Likely_pathogenic|association                            1       1       1
# Likely_pathogenic|other                                  1       1       1
# Likely_pathogenic|risk_factor                            1       1       1
# Likely_risk_allele                                       5       5       5
# Pathogenic                                            3110    3110    3110
# Pathogenic/Likely_pathogenic                           850     850     850
# Pathogenic/Likely_pathogenic/Likely_risk_allele          1       1       1
# Pathogenic/Likely_pathogenic/Pathogenic;_low_pe...       1       1       1
# Pathogenic/Likely_pathogenic|other                       4       4       4
# Pathogenic/Likely_risk_allele                            1       1       1
# Pathogenic|association                                   3       3       3
# Uncertain_risk_allele                                    7       7       7
# Uncertain_significance                              332912  332912  332912
# Uncertain_significance/Uncertain_risk_allele            34      34      34
# Uncertain_significance|association                       1       1       1
# Uncertain_significance|drug_response                     1       1       1
# association                                             26      26      26
# drug_response                                           36      36      36
# not_provided                                           602     602     602
# other                                                   19      19      19
# protective                                               2       2       2
# risk_factor                                             25      25      25
#
#                                                     N_disordered  N_ordered  \
# signi
# Affects                                                        7          7
# Benign                                                     10494      10494
# Benign/Likely_benign                                        3919       3919
# Benign/Likely_benign|association                               1          1
# Benign/Likely_benign|other|risk_factor                         1          1
# Benign|association                                             1          1
# Conflicting_classifications_of_pathogenicity               17464      17464
# Conflicting_classifications_of_pathogenicity|as...             1          1
# Conflicting_classifications_of_pathogenicity|ri...             2          2
# Likely_benign                                              24292      24292
# Likely_pathogenic                                           3243       3243
# Likely_pathogenic/Likely_risk_allele                           1          1
# Likely_pathogenic;_low_penetrance                              1          1
# Likely_pathogenic|association                                  1          1
# Likely_pathogenic|other                                        1          1
# Likely_pathogenic|risk_factor                                  1          1
# Likely_risk_allele                                             5          5
# Pathogenic                                                  3110       3110
# Pathogenic/Likely_pathogenic                                 850        850
# Pathogenic/Likely_pathogenic/Likely_risk_allele                1          1
# Pathogenic/Likely_pathogenic/Pathogenic;_low_pe...             1          1
# Pathogenic/Likely_pathogenic|other                             4          4
# Pathogenic/Likely_risk_allele                                  1          1
# Pathogenic|association                                         3          3
# Uncertain_risk_allele                                          7          7
# Uncertain_significance                                    332912     332912
# Uncertain_significance/Uncertain_risk_allele                  34         34
# Uncertain_significance|association                             1          1
# Uncertain_significance|drug_response                           1          1
# association                                                   26         26
# drug_response                                                 36         36
# not_provided                                                 602        602
# other                                                         19         19
# protective                                                     2          2
# risk_factor                                                   25         25
#
#                                                      varID  change    orig  \
# signi
# Affects                                                  7       7       7
# Benign                                               10494   10494   10494
# Benign/Likely_benign                                  3919    3919    3919
# Benign/Likely_benign|association                         1       1       1
# Benign/Likely_benign|other|risk_factor                   1       1       1
# Benign|association                                       1       1       1
# Conflicting_classifications_of_pathogenicity         17464   17464   17464
# Conflicting_classifications_of_pathogenicity|as...       1       1       1
# Conflicting_classifications_of_pathogenicity|ri...       2       2       2
# Likely_benign                                        24292   24292   24292
# Likely_pathogenic                                     3243    3243    3243
# Likely_pathogenic/Likely_risk_allele                     1       1       1
# Likely_pathogenic;_low_penetrance                        1       1       1
# Likely_pathogenic|association                            1       1       1
# Likely_pathogenic|other                                  1       1       1
# Likely_pathogenic|risk_factor                            1       1       1
# Likely_risk_allele                                       5       5       5
# Pathogenic                                            3110    3110    3110
# Pathogenic/Likely_pathogenic                           850     850     850
# Pathogenic/Likely_pathogenic/Likely_risk_allele          1       1       1
# Pathogenic/Likely_pathogenic/Pathogenic;_low_pe...       1       1       1
# Pathogenic/Likely_pathogenic|other                       4       4       4
# Pathogenic/Likely_risk_allele                            1       1       1
# Pathogenic|association                                   3       3       3
# Uncertain_risk_allele                                    7       7       7
# Uncertain_significance                              332912  332912  332912
# Uncertain_significance/Uncertain_risk_allele            34      34      34
# Uncertain_significance|association                       1       1       1
# Uncertain_significance|drug_response                     1       1       1
# association                                             26      26      26
# drug_response                                           36      36      36
# not_provided                                           602     602     602
# other                                                   19      19      19
# protective                                               2       2       2
# risk_factor                                             25      25      25
#
#                                                        pos     mut    wtRe  \
# signi
# Affects                                                  7       7       7
# Benign                                               10494   10494   10494
# Benign/Likely_benign                                  3919    3919    3919
# Benign/Likely_benign|association                         1       1       1
# Benign/Likely_benign|other|risk_factor                   1       1       1
# Benign|association                                       1       1       1
# Conflicting_classifications_of_pathogenicity         17464   17464   17464
# Conflicting_classifications_of_pathogenicity|as...       1       1       1
# Conflicting_classifications_of_pathogenicity|ri...       2       2       2
# Likely_benign                                        24292   24292   24292
# Likely_pathogenic                                     3243    3243    3243
# Likely_pathogenic/Likely_risk_allele                     1       1       1
# Likely_pathogenic;_low_penetrance                        1       1       1
# Likely_pathogenic|association                            1       1       1
# Likely_pathogenic|other                                  1       1       1
# Likely_pathogenic|risk_factor                            1       1       1
# Likely_risk_allele                                       5       5       5
# Pathogenic                                            3110    3110    3110
# Pathogenic/Likely_pathogenic                           850     850     850
# Pathogenic/Likely_pathogenic/Likely_risk_allele          1       1       1
# Pathogenic/Likely_pathogenic/Pathogenic;_low_pe...       1       1       1
# Pathogenic/Likely_pathogenic|other                       4       4       4
# Pathogenic/Likely_risk_allele                            1       1       1
# Pathogenic|association                                   3       3       3
# Uncertain_risk_allele                                    7       7       7
# Uncertain_significance                              332912  332912  332912
# Uncertain_significance/Uncertain_risk_allele            34      34      34
# Uncertain_significance|association                       1       1       1
# Uncertain_significance|drug_response                     1       1       1
# association                                             26      26      26
# drug_response                                           36      36      36
# not_provided                                           602     602     602
# other                                                   19      19      19
# protective                                               2       2       2
# risk_factor                                             25      25      25
#
#                                                      mutRe  wtRe_local  \
# signi
# Affects                                                  7           7
# Benign                                               10494       10494
# Benign/Likely_benign                                  3919        3919
# Benign/Likely_benign|association                         1           1
# Benign/Likely_benign|other|risk_factor                   1           1
# Benign|association                                       1           1
# Conflicting_classifications_of_pathogenicity         17464       17464
# Conflicting_classifications_of_pathogenicity|as...       1           1
# Conflicting_classifications_of_pathogenicity|ri...       2           2
# Likely_benign                                        24292       24292
# Likely_pathogenic                                     3243        3243
# Likely_pathogenic/Likely_risk_allele                     1           1
# Likely_pathogenic;_low_penetrance                        1           1
# Likely_pathogenic|association                            1           1
# Likely_pathogenic|other                                  1           1
# Likely_pathogenic|risk_factor                            1           1
# Likely_risk_allele                                       5           5
# Pathogenic                                            3110        3110
# Pathogenic/Likely_pathogenic                           850         850
# Pathogenic/Likely_pathogenic/Likely_risk_allele          1           1
# Pathogenic/Likely_pathogenic/Pathogenic;_low_pe...       1           1
# Pathogenic/Likely_pathogenic|other                       4           4
# Pathogenic/Likely_risk_allele                            1           1
# Pathogenic|association                                   3           3
# Uncertain_risk_allele                                    7           7
# Uncertain_significance                              332912      332912
# Uncertain_significance/Uncertain_risk_allele            34          34
# Uncertain_significance|association                       1           1
# Uncertain_significance|drug_response                     1           1
# association                                             26          26
# drug_response                                           36          36
# not_provided                                           602         602
# other                                                   19          19
# protective                                               2           2
# risk_factor                                             25          25
#
#                                                     mutRe_local  changeType  \
# signi
# Affects                                                       7           7
# Benign                                                    10494       10494
# Benign/Likely_benign                                       3919        3919
# Benign/Likely_benign|association                              1           1
# Benign/Likely_benign|other|risk_factor                        1           1
# Benign|association                                            1           1
# Conflicting_classifications_of_pathogenicity              17464       17464
# Conflicting_classifications_of_pathogenicity|as...            1           1
# Conflicting_classifications_of_pathogenicity|ri...            2           2
# Likely_benign                                             24292       24292
# Likely_pathogenic                                          3243        3243
# Likely_pathogenic/Likely_risk_allele                          1           1
# Likely_pathogenic;_low_penetrance                             1           1
# Likely_pathogenic|association                                 1           1
# Likely_pathogenic|other                                       1           1
# Likely_pathogenic|risk_factor                                 1           1
# Likely_risk_allele                                            5           5
# Pathogenic                                                 3110        3110
# Pathogenic/Likely_pathogenic                                850         850
# Pathogenic/Likely_pathogenic/Likely_risk_allele               1           1
# Pathogenic/Likely_pathogenic/Pathogenic;_low_pe...            1           1
# Pathogenic/Likely_pathogenic|other                            4           4
# Pathogenic/Likely_risk_allele                                 1           1
# Pathogenic|association                                        3           3
# Uncertain_risk_allele                                         7           7
# Uncertain_significance                                   332912      332912
# Uncertain_significance/Uncertain_risk_allele                 34          34
# Uncertain_significance|association                            1           1
# Uncertain_significance|drug_response                          1           1
# association                                                  26          26
# drug_response                                                36          36
# not_provided                                                602         602
# other                                                        19          19
# protective                                                    2           2
# risk_factor                                                  25          25
#
#                                                     res_disorder  disease
# signi
# Affects                                                        7        7
# Benign                                                     10494    10494
# Benign/Likely_benign                                        3919     3919
# Benign/Likely_benign|association                               1        1
# Benign/Likely_benign|other|risk_factor                         1        1
# Benign|association                                             1        1
# Conflicting_classifications_of_pathogenicity               17464    17464
# Conflicting_classifications_of_pathogenicity|as...             1        1
# Conflicting_classifications_of_pathogenicity|ri...             2        2
# Likely_benign                                              24292    24292
# Likely_pathogenic                                           3243     3243
# Likely_pathogenic/Likely_risk_allele                           1        1
# Likely_pathogenic;_low_penetrance                              1        1
# Likely_pathogenic|association                                  1        1
# Likely_pathogenic|other                                        1        1
# Likely_pathogenic|risk_factor                                  1        1
# Likely_risk_allele                                             5        5
# Pathogenic                                                  3110     3110
# Pathogenic/Likely_pathogenic                                 850      850
# Pathogenic/Likely_pathogenic/Likely_risk_allele                1        1
# Pathogenic/Likely_pathogenic/Pathogenic;_low_pe...             1        1
# Pathogenic/Likely_pathogenic|other                             4        4
# Pathogenic/Likely_risk_allele                                  1        1
# Pathogenic|association                                         3        3
# Uncertain_risk_allele                                          7        7
# Uncertain_significance                                    332912   332912
# Uncertain_significance/Uncertain_risk_allele                  34       34
# Uncertain_significance|association                             1        1
# Uncertain_significance|drug_response                           1        1
# association                                                   26       26
# drug_response                                                 36       36
# not_provided                                                 602      602
# other                                                         19       19
# protective                                                     2        2
# risk_factor                                                   25       25
